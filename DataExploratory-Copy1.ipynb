# %%
import pandas as pd
import json

# %% [markdown]
# > ATIVIDADE DEPUTADOS

# %%
data_activity = json.loads(open("./../../../../../../Downloads/AtividadeDeputadoXIII.json").read())

# %% [markdown]
# # Demographic

# %% [markdown]
# __Total__

# %%
data_activity["ArrayOfAtividadeDeputado"]["AtividadeDeputado"][2]["deputado"]
# Out:
# {'depCPDes': 'PORTO',
#  'depCPId': '13',
#  'depCadId': '462',
#  'depGP': {'pt_ar_wsgode_objectos_DadosSituacaoGP': {'gpDtInicio': '2015-10-23',
#    'gpId': '4465',
#    'gpSigla': 'PS'}},
#  'depId': '8481',
#  'depNomeCompleto': 'ALBERTO DE SOUSA MARTINS',
#  'depNomeParlamentar': 'ALBERTO MARTINS',
#  'depSituacao': {'pt_ar_wsgode_objectos_DadosSituacaoDeputado': [{'sioDes': 'Renunciou',
#     'sioDtInicio': '2017-07-20'},
#    {'sioDes': 'Efetivo',
#     'sioDtFim': '2017-07-20',
#     'sioDtInicio': '2015-10-23'}]},
#  'legDes': 'XIII'}

# %%
data_activity["ArrayOfAtividadeDeputado"]["AtividadeDeputado"][2]["deputado"]["depNomeCompleto"]
# Out:
# 'ALBERTO DE SOUSA MARTINS'

# %% [markdown]
# __Party__

# %%
data_activity["ArrayOfAtividadeDeputado"]["AtividadeDeputado"][2]["deputado"]["depGP"]["pt_ar_wsgode_objectos_DadosSituacaoGP"]["gpSigla"]
# Out:
# 'PS'

# %% [markdown]
# __District__

# %%
counter = 0
for i in range(len(data_activity["ArrayOfAtividadeDeputado"]["AtividadeDeputado"])):
    counter +=1
    print(data_activity["ArrayOfAtividadeDeputado"]["AtividadeDeputado"][i]["deputado"]["depCPDes"])
# Out:
# VIANA DO CASTELO
# BRAGANÇA
# PORTO
# PORTO
# CASTELO BRANCO
# PORTO
# AVEIRO
# SETÚBAL
# LISBOA
# COIMBRA
# FARO
# PORTO
# LISBOA
# LISBOA
# PORTO
# SETÚBAL
# LISBOA
# PORTO
# GUARDA
# PORTO
# VISEU
# AVEIRO
# AVEIRO
# LISBOA
# ÉVORA
# FARO
# SANTARÉM
# SANTARÉM
# VISEU
# VISEU
# VIANA DO CASTELO
# LEIRIA
# AVEIRO
# AÇORES
# LISBOA
# VILA REAL
# LEIRIA
# PORTO
# AÇORES
# AVEIRO
# SETÚBAL
# SETÚBAL
# ÉVORA
# PORTO
# BRAGA
# PORTO
# AVEIRO
# VIANA DO CASTELO
# EUROPA
# AÇORES
# PORTO
# SANTARÉM
# FORA DA EUROPA
# GUARDA
# MADEIRA
# LISBOA
# SETÚBAL
# PORTO
# PORTO
# BRAGA
# PORTO
# PORTO
# PORTALEGRE
# FARO
# PORTO
# PORTO
# BRAGA
# LISBOA
# PORTO
# BRAGA
# SANTARÉM
# LISBOA
# LISBOA
# SETÚBAL
# LISBOA
# COIMBRA
# BRAGA
# VIANA DO CASTELO
# PORTO
# MADEIRA
# VISEU
# CASTELO BRANCO
# SETÚBAL
# COIMBRA
# LEIRIA
# FARO
# PORTO
# BRAGA
# AVEIRO
# PORTO
# LISBOA
# LISBOA
# AVEIRO
# PORTO
# SETÚBAL
# SETÚBAL
# PORTO
# VILA REAL
# PORTO
# LISBOA
# LEIRIA
# VISEU
# COIMBRA
# LISBOA
# AVEIRO
# ...

# %%
print(counter)
# Out:
# 298

# %% [markdown]
# # Activity

# %% [markdown]
# __Classes__

# %%
for i in data_activity["ArrayOfAtividadeDeputado"]["AtividadeDeputado"][2]["AtividadeDeputadoList"]["pt_gov_ar_wsar_objectos_ActividadeOut"]:
    print(i)
# Out:
# ini
# req
# intev
# actP
# dlP
# rel
# eventos
# cms
# dadosLegisDeputado
# audiencias
# audicoes

# %% [markdown]
# __Initiatives__

# %%
data_activity["ArrayOfAtividadeDeputado"]["AtividadeDeputado"][2]["AtividadeDeputadoList"]["pt_gov_ar_wsar_objectos_ActividadeOut"]["ini"]["pt_gov_ar_wsar_objectos_IniciativasOut"]
# Out:
# [{'iniId': '41504',
#   'iniNr': '937',
#   'iniSelLg': 'XIII',
#   'iniSelNr': '2',
#   'iniTi': 'Política de Coesão Pós-2020',
#   'iniTp': 'R',
#   'iniTpdesc': 'Projeto de Resolução'},
#  {'iniId': '41385',
#   'iniNr': '877',
#   'iniSelLg': 'XIII',
#   'iniSelNr': '2',
#   'iniTi': 'Pela criação de um Museu Nacional da Emigração',
#   'iniTp': 'R',
#   'iniTpdesc': 'Projeto de Resolução'},
#  {'iniId': '41384',
#   'iniNr': '876',
#   'iniSelLg': 'XIII',
#   'iniSelNr': '2',
#   'iniTi': 'Pela valorização do ensino da história da emigração portuguesa',
#   'iniTp': 'R',
#   'iniTpdesc': 'Projeto de Resolução'},
#  {'iniId': '40776',
#   'iniNr': '546',
#   'iniSelLg': 'XIII',
#   'iniSelNr': '2',
#   'iniTi': 'Promove a melhoria do acesso aos cursos do Ensino de Português no Estrangeiro e promove a sua qualidade pedagógica',
#   'iniTp': 'R',
#   'iniTpdesc': 'Projeto de Resolução'}]

# %% [markdown]
# __Interventions__

# %%
data_activity["ArrayOfAtividadeDeputado"]["AtividadeDeputado"][2]["AtividadeDeputadoList"]["pt_gov_ar_wsar_objectos_ActividadeOut"]["intev"]["pt_gov_ar_wsar_objectos_IntervencoesOut"]
# Out:
# [{'intId': '215221',
#   'intSu': 'Renúncia ao mandato do Deputado Alberto Martins (PS)',
#   'pubDar': '61-62',
#   'pubDtreu': '2017-07-19',
#   'pubLg': 'XIII',
#   'pubNr': '109',
#   'pubSl': '2',
#   'pubSup': '.',
#   'pubTp': 'D',
#   'tinDs': 'Intervenção'},
#  {'intId': '210513',
#   'intSu': 'Sessão Solene Comemorativa do 43º. aniversário do 25 de Abril.',
#   'pubDar': '10-12',
#   'pubDtreu': '2017-04-25',
#   'pubLg': 'XIII',
#   'pubNr': '80',
#   'pubSl': '2',
#   'pubSup': '.',
#   'pubTp': 'D',
#   'tinDs': 'Intervenção'},
#  {'intId': '212363',
#   'intSu': 'Voto de Condenação em defesa dos valores da relação transatlântica',
#   'pubDar': '50-51',
#   'pubDtreu': '2017-02-03',
#   'pubLg': 'XIII',
#   'pubNr': '47',
#   'pubSl': '2',
#   'pubSup': '.',
#   'pubTp': 'D',
#   'tinDs': 'Declaração de voto'},
#  {'intId': '212355',
# ...

# %% [markdown]
# > __REGISTO BIOGRAFICO__

# %%
data_bio = json.loads(open("/home/boturon/proj/git/parlamento/data/registo-biografico-02.json").read())

# %% [markdown]
# __id__

# %%
data_bio["RegistoBiografico"]["RegistoBiograficoList"]["pt_ar_wsgode_objectos_DadosRegistoBiograficoWeb"][3]#["cadId"]
# Out:
# {'cadActividadeOrgaos': None,
#  'cadDeputadoLegis': {'pt_ar_wsgode_objectos_DadosDeputadoLegis': [{'ceDes': 'PORTO',
#     'depNomeParlamentar': 'Adalberto Neiva',
#     'gpDes': 'Centro Democrático Social',
#     'gpSigla': 'CDS',
#     'legDes': 'III',
#     'parDes': 'Centro Democrático Social',
#     'parSigla': 'CDS'},
#    {'ceDes': 'PORTO',
#     'depNomeParlamentar': 'Adalberto Neiva',
#     'gpDes': 'Centro Democrático Social',
#     'gpSigla': 'CDS',
#     'legDes': 'II',
#     'parDes': 'Aliança Democrática',
#     'parSigla': 'AD'},
#    {'ceDes': 'PORTO',
#     'depNomeParlamentar': 'Adalberto Neiva',
#     'gpDes': 'Centro Democrático Social',
#     'gpSigla': 'CDS',
#     'legDes': 'IB',
#     'parDes': 'Aliança Democrática',
#     'parSigla': 'AD'},
#    {'ceDes': 'PORTO',
#     'depNomeParlamentar': 'Adalberto Neiva',
#     'gpDes': 'Centro Democrático Social',
#     'gpSigla': 'CDS',
#     'legDes': 'IA',
#     'parDes': 'Centro Democrático Social',
# ...

# %% [markdown]
# > __DIPLOMAS__

# %%
data_diplomaII = json.loads(open("./../../../../../../proj/law_success/data/diplomas/DiplomasII.json").read())

# %%
for i in data_diplomaII["ArrayOfPt_gov_ar_objectos_diplomas_DetalhePesquisaDiplomasOut"]["pt_gov_ar_objectos_diplomas_DetalhePesquisaDiplomasOut"]:
    print(i)
# Out:
# {'id': '13177', 'numero': '56', 'titulo': 'Lei da Nacionalidade', 'tipo': 'Decreto da Assembleia', 'legislatura': 'II', 'sessao': '1', 'anoCivil': '1981', 'linkTexto': None, 'publicacao': {'pt_gov_ar_objectos_PublicacoesOut': {'pubNr': '99', 'pubTipo': 'DAR II série', 'pubTp': 'K', 'pubLeg': 'II', 'pubSL': '1', 'supl': '.', 'pubdt': '1981-08-01', 'pag': {'string': '3239-3243'}, 'idPag': '341331', 'idInt': None, 'idAct': None, 'URLDiario': 'http://debates.parlamento.pt/catalogo/r3/dar/s2/02/01/099/1981-08-01/3239?pgs=3239-3243&org=PLC', 'idDeb': None}}, 'iniciativas': {'pt_gov_ar_objectos_iniciativas_DetalhePesquisaIniciativasOut': [{'iniNr': '29', 'iniTipo': 'P', 'iniLinkTexto': None, 'iniId': '30801'}, {'iniNr': '53', 'iniTipo': 'J', 'iniLinkTexto': None, 'iniId': '30352'}, {'iniNr': '164', 'iniTipo': 'J', 'iniLinkTexto': None, 'iniId': '30469'}]}, 'tp': 'D', 'orcamContasGerencia': None}
# ...

# %%
data_diplomaII

# %% [markdown]
# > __INICIATIVAS__

# %%
data_initiativeII = json.loads(open("/home/boturon/proj/git/parlamento/data/iniciativas-02.json").read())

# %%
data_initiativeII["ArrayOfPt_gov_ar_objectos_iniciativas_DetalhePesquisaIniciativasOut"]["pt_gov_ar_objectos_iniciativas_DetalhePesquisaIniciativasOut"]
# Out:
# [{'dataFimleg': '1981-10-14',
#   'dataInicioleg': '1980-11-13',
#   'iniAutorDeputados': {'pt_gov_ar_objectos_iniciativas_AutoresDeputadosOut': [{'GP': 'PCP',
#      'idCadastro': '2126',
#      'nome': 'Zita Seabra'},
#     {'GP': 'PCP', 'idCadastro': '3020', 'nome': 'JOSÉ MANUEL MENDES'},
#     {'GP': 'PCP', 'idCadastro': '2948', 'nome': 'Carlos Alfredo Brito'},
#     {'GP': 'PCP', 'idCadastro': '3377', 'nome': 'Álvaro Oliveira'},
#     {'GP': 'PCP', 'idCadastro': '3176', 'nome': 'ALDA NOGUEIRA'},
#     {'GP': 'PCP', 'idCadastro': '210', 'nome': 'Jerónimo de Sousa'},
#     {'GP': 'PCP', 'idCadastro': '3380', 'nome': 'MANUEL LOPES'},
#     {'GP': 'PCP', 'idCadastro': '569', 'nome': 'Ilda Figueiredo'},
#     {'GP': 'PCP', 'idCadastro': '1521', 'nome': 'Vital Moreira'},
#     {'GP': 'PCP', 'idCadastro': '3385', 'nome': 'Lino Carvalho Lima'},
#     {'GP': 'PCP', 'idCadastro': '3628', 'nome': 'Armando Teixeira Silva'}]},
# ...

# %% [markdown]
# ## Authors

# %%
data_initiativeII["ArrayOfPt_gov_ar_objectos_iniciativas_DetalhePesquisaIniciativasOut"]["pt_gov_ar_objectos_iniciativas_DetalhePesquisaIniciativasOut"][5]
# Out:
# {'dataFimleg': '1981-10-14',
#  'dataInicioleg': '1980-11-13',
#  'iniAutorDeputados': {'pt_gov_ar_objectos_iniciativas_AutoresDeputadosOut': [{'GP': 'PS',
#     'idCadastro': '2933',
#     'nome': 'António Esteves'},
#    {'GP': 'PS', 'idCadastro': '196', 'nome': 'LUÍS FILIPE MADEIRA'},
#    {'GP': 'PS', 'idCadastro': '3523', 'nome': 'Júlio Carrapato'}]},
#  'iniAutorGruposParlamentares': {'pt_gov_ar_objectos_AutoresGruposParlamentaresOut': {'GP': 'PS'}},
#  'iniAutorOutros': {'iniAutorComissao': None,
#   'nome': 'Deputados',
#   'sigla': 'D'},
#  'iniDescTipo': 'Projeto de Lei',
#  'iniEventos': {'pt_gov_ar_objectos_iniciativas_EventosOut': [{'codigoFase': '21',
#     'dataFase': '1981-06-30',
#     'evtId': '3',
#     'fase': 'Anúncio',
#     'oevId': '233324'},
#    {'codigoFase': '50',
#     'dataFase': '1981-07-01',
#     'evtId': '51',
#     'fase': 'Publicação',
#     'oevId': '233325',
# ...

# %%
data_initiativeII["ArrayOfPt_gov_ar_objectos_iniciativas_DetalhePesquisaIniciativasOut"]["pt_gov_ar_objectos_iniciativas_DetalhePesquisaIniciativasOut"][5]["iniAutorDeputados"]["pt_gov_ar_objectos_iniciativas_AutoresDeputadosOut"]
# Out:
# [{'GP': 'PS', 'idCadastro': '2933', 'nome': 'António Esteves'},
#  {'GP': 'PS', 'idCadastro': '196', 'nome': 'LUÍS FILIPE MADEIRA'},
#  {'GP': 'PS', 'idCadastro': '3523', 'nome': 'Júlio Carrapato'}]

# %% [markdown]
# ## Results

# %%
data_initiativeXI = json.loads(open("/home/boturon/proj/git/parlamento/data/iniciativas-11.json").read())

# %%
data_initiativeXI["ArrayOfPt_gov_ar_objectos_iniciativas_DetalhePesquisaIniciativasOut"]["pt_gov_ar_objectos_iniciativas_DetalhePesquisaIniciativasOut"][6]["iniEventos"]["pt_gov_ar_objectos_iniciativas_EventosOut"][5]["comissao"]["pt_gov_ar_objectos_iniciativas_ComissoesIniOut"]["votacao"]["resultado"]
# Out:
# 'Rejeitado'

# %% [markdown]
# # Get result
